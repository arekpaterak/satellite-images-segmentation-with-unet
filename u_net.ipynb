# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchinfo import summary

import albumentations as A
from albumentations.pytorch import ToTensorV2

import segmentation_models_pytorch as smp

from model import UNet
from datasets.dataset import LandcoverDataset

# %%
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(DEVICE)
# Out:
# cuda

# %%
TRAIN_IMG_DIR = "data/landcover/train/images/"
TRAIN_MASK_DIR = "data/landcover/train/masks/"
VAL_IMG_DIR = "data/landcover/val/images/"
VAL_MASK_DIR = "data/landcover/val/masks/"
TEST_IMG_DIR = "data/landcover/test/images/"
TEST_MASK_DIR = "data/landcover/test/masks/"

# %%
LEARNING_RATE = 1e-4
BATCH_SIZE = 16
NUM_EPOCHS = 3

criterion = nn.CrossEntropyLoss()

# %%
train_transforms = A.Compose(
    [
        A.Resize(height=64, width=64),
        A.Rotate(limit=35, p=1.0),
        A.Normalize(
            mean=[0.0, 0.0, 0.0],
            std=[1.0, 1.0, 1.0],
            max_pixel_value=255.0,
        ),
        ToTensorV2(),
    ],
)

val_transforms = A.Compose(
    [
        A.Resize(height=64, width=64),
        A.Normalize(
            mean=[0.0, 0.0, 0.0],
            std=[1.0, 1.0, 1.0],
            max_pixel_value=255.0,
        ),
        ToTensorV2(),
    ],
)

# %%
train_dataset = LandcoverDataset(
    image_dir=TRAIN_IMG_DIR,
    mask_dir=TRAIN_MASK_DIR,
    transform=train_transforms,
)

val_dataset = LandcoverDataset(
    image_dir=VAL_IMG_DIR,
    mask_dir=VAL_MASK_DIR,
    transform=val_transforms,
)

train_dataloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=BATCH_SIZE, shuffle=True
)

val_dataloader = torch.utils.data.DataLoader(
    val_dataset, batch_size=BATCH_SIZE, shuffle=False
)

# %%
masks_to_labels = {
    0: "Other",
    1: "Buildings",
    2: "Woodlands",
    3: "Water",
    4: "Roads",
}

# %%
import numpy as np
import matplotlib.pyplot as plt

for i in range(3):
    image, mask = train_dataset[i]

    fig, axs = plt.subplots(1, 2, figsize=(10, 5))

    axs[0].imshow(np.transpose(image, (1, 2, 0)))
    axs[0].set_title("Image")

    mask = mask.squeeze()

    m = axs[1].imshow(mask, vmin=0, vmax=4)
    axs[1].set_title("Mask")
    plt.colorbar(m, ax=axs[1], ticks=[0, 1, 2, 3, 4])

    for ax in axs:
        ax.axis("off")

    plt.show()

# %%
model = UNet(
    in_channels=3,
    n_classes=5,
    features=[64, 128, 256],
)

summary(model, input_size=(16, 3, 64, 64))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# UNet                                     [16, 5, 64, 64]           --
# ├─ModuleList: 1-5                        --                        (recursive)
# │    └─DoubleConv: 2-1                   [16, 64, 64, 64]          --
# │    │    └─Sequential: 3-1              [16, 64, 64, 64]          38,848
# ├─MaxPool2d: 1-2                         [16, 64, 32, 32]          --
# ├─ModuleList: 1-5                        --                        (recursive)
# │    └─DoubleConv: 2-2                   [16, 128, 32, 32]         --
# │    │    └─Sequential: 3-2              [16, 128, 32, 32]         221,696
# ├─MaxPool2d: 1-4                         [16, 128, 16, 16]         --
# ├─ModuleList: 1-5                        --                        (recursive)
# │    └─DoubleConv: 2-3                   [16, 256, 16, 16]         --
# │    │    └─Sequential: 3-3              [16, 256, 16, 16]         885,760
# ├─MaxPool2d: 1-6                         [16, 256, 8, 8]           --
# ├─DoubleConv: 1-7                        [16, 512, 8, 8]           --
# │    └─Sequential: 2-4                   [16, 512, 8, 8]           --
# │    │    └─Conv2d: 3-4                  [16, 512, 8, 8]           1,179,648
# │    │    └─BatchNorm2d: 3-5             [16, 512, 8, 8]           1,024
# │    │    └─ReLU: 3-6                    [16, 512, 8, 8]           --
# │    │    └─Conv2d: 3-7                  [16, 512, 8, 8]           2,359,296
# │    │    └─BatchNorm2d: 3-8             [16, 512, 8, 8]           1,024
# │    │    └─ReLU: 3-9                    [16, 512, 8, 8]           --
# ├─ModuleList: 1-8                        --                        --
# │    └─ConvTranspose2d: 2-5              [16, 256, 16, 16]         524,544
# │    └─DoubleConv: 2-6                   [16, 256, 16, 16]         --
# │    │    └─Sequential: 3-10             [16, 256, 16, 16]         1,770,496
# │    └─ConvTranspose2d: 2-7              [16, 128, 32, 32]         131,200
# │    └─DoubleConv: 2-8                   [16, 128, 32, 32]         --
# │    │    └─Sequential: 3-11             [16, 128, 32, 32]         442,880
# │    └─ConvTranspose2d: 2-9              [16, 64, 64, 64]          32,832
# │    └─DoubleConv: 2-10                  [16, 64, 64, 64]          --
# │    │    └─Sequential: 3-12             [16, 64, 64, 64]          110,848
# ├─Conv2d: 1-9                            [16, 5, 64, 64]           325
# ==========================================================================================
# Total params: 7,700,421
# Trainable params: 7,700,421
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 41.62
# ==========================================================================================
# Input size (MB): 0.79
# Forward/backward pass size (MB): 547.88
# Params size (MB): 30.80
# Estimated Total Size (MB): 579.47
# ==========================================================================================

# %%
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
criterion = nn.CrossEntropyLoss()

# %%
NUM_EPOCHS = 1

for epoch in range(NUM_EPOCHS):
    print('\n----------------------------------')
    print(f'EPOCH: {epoch + 1}/{NUM_EPOCHS}')

    model.train()

    train_loss = 0.0
    for batch_idx, (image, target_mask) in enumerate(train_dataloader):
        print(f'Batch: {batch_idx + 1}/{len(train_dataloader)}', end="\r")
        image = image.to(DEVICE)
        target_mask = target_mask.float().to(device=DEVICE)

        # forward
        logits = model(image)

        target_mask = target_mask.long()
        target_mask = target_mask.squeeze(1)

        loss = criterion(logits, target_mask)

        # backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        train_loss += loss.item()

    train_loss /= len(train_dataloader)

    model.eval()
    num_correct = 0
    num_pixels = 0

    dice_score_acc = 0

    with torch.no_grad():
        for x, y in val_dataloader:
            x = x.to(DEVICE)
            y = y.to(DEVICE)
            logits = model(x)
            probs = F.softmax(logits, dim=1)
            preds = torch.argmax(probs, dim=1)

            num_correct += (preds == y.squeeze()).sum()
            num_pixels += torch.numel(preds)

            dice_score_acc += 2 * (preds * y.squeeze()).sum() / (torch.numel(preds) + torch.numel(y.squeeze()))

    avg_dice_score = dice_score_acc / len(val_dataloader)

    print(
        f"Train Loss: {train_loss}, Validation Accuracy: {num_correct / num_pixels}, Validation Dice Score: {avg_dice_score}"
    )
# Out:
# ----------------------------------
# EPOCH: 1/1
# Train Loss: 0.4036135153066592, Validation Accuracy: 0.8702347278594971, Validation Dice Score: 1.714721918106079

# %%
model.eval()
for i in range(5):
    image, mask = val_dataset[i + 200]
    image = image.unsqueeze(0)
    with torch.no_grad():
        image = image.to(DEVICE)
        logits = model(image)
        probs = F.softmax(logits, dim=1)
        preds = torch.argmax(probs, dim=1)

        print(mask.shape, preds.shape)

        print((mask == preds.cpu()).sum() / torch.numel(mask))

    fig, axs = plt.subplots(1, 3, figsize=(15, 5))

    axs[0].imshow(np.transpose(image.squeeze(0).cpu(), (1, 2, 0)))
    axs[0].set_title("Image")

    mask = mask.squeeze()

    m = axs[1].imshow(mask, vmin=0, vmax=4)
    axs[1].set_title("Mask")
    plt.colorbar(m, ax=axs[1], ticks=[0, 1, 2, 3, 4])

    p = axs[2].imshow(preds.cpu().squeeze(0), vmin=0, vmax=4)
    axs[2].set_title("Prediction")
    plt.colorbar(p, ax=axs[2], ticks=[0, 1, 2, 3, 4])

    for ax in axs:
        ax.axis("off")

    plt.show()
# Out:
# torch.Size([1, 64, 64]) torch.Size([1, 64, 64])
# tensor(0.9985)
# torch.Size([1, 64, 64]) torch.Size([1, 64, 64])
# tensor(0.9836)
# torch.Size([1, 64, 64]) torch.Size([1, 64, 64])
# tensor(1.)
# torch.Size([1, 64, 64]) torch.Size([1, 64, 64])
# tensor(0.8557)
# torch.Size([1, 64, 64]) torch.Size([1, 64, 64])
# tensor(0.9719)

# %%
test_dataset = LandcoverDataset(
    image_dir=TEST_IMG_DIR,
    mask_dir=TEST_MASK_DIR,
    transform=val_transforms,
)

test_dataloader = torch.utils.data.DataLoader(
    test_dataset, batch_size=BATCH_SIZE, shuffle=False
)

model.eval()

num_correct = 0
num_pixels = 0

dice_score_acc

with torch.no_grad():
    for x, y in test_dataloader:
        x = x.to(DEVICE)
        y = y.to(DEVICE)
        logits = model(x)
        probs = F.softmax(logits, dim=1)
        preds = torch.argmax(probs, dim=1)

        num_correct += (preds == y.squeeze()).sum()
        num_pixels += torch.numel(preds)

        dice_score_acc += 2 * (preds * y.squeeze()).sum() / (torch.numel(preds) + torch.numel(y.squeeze()))

avg_dice_score = dice_score_acc / len(test_dataloader)

print(
    f"Test Accuracy: {num_correct / num_pixels}, Test Dice Score: {avg_dice_score}"
)
# Out:
# Test Accuracy: 0.8754485249519348, Test Dice Score: 4.7718706130981445

# %%
# save the model

torch.save(model.state_dict(), "model.pth")
